# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahul21388/Python-Chess-Game/blob/main/Project_Chess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Stage 1

# %%
import matplotlib.pyplot as plt

# Chessboard settings
BOARD_SIZE = 8
SQUARE_COLORS = ["#e5c69f", "#b88b4a"]
#SQUARE_COLORS = ["#d2b48c", "#769656"]  # Tan & Green (Stage 1)

# Stage 1 board may have used #769656 (green) and #d2b48c (tan). # Light brown (tan) & dark green
# Current board uses lighter brown shades (#e5c69f and #b88b4a).

# e5c69f = light brown
# b88b4a = dark brown
# 769656 = dark green
# d2b48c = light

# Standard chessboard setup
chess_board = [
    ["bR", "bN", "bB", "bQ", "bK", "bB", "bN", "bR"],
    ["bP", "bP", "bP", "bP", "bP", "bP", "bP", "bP"],
    [".", ".", ".", ".", ".", ".", ".", "."],
    [".", ".", ".", ".", ".", ".", ".", "."],
    [".", ".", ".", ".", ".", ".", ".", "."],
    [".", ".", ".", ".", ".", ".", ".", "."],
    ["wP", "wP", "wP", "wP", "wP", "wP", "wP", "wP"],
    ["wR", "wN", "wB", "wQ", "wK", "wB", "wN", "wR"]
]

# Unicode mapping for chess pieces
piece_symbols = {
    "bR": "♜", "bN": "♞", "bB": "♝", "bQ": "♛", "bK": "♚", "bP": "♟",
    "wR": "♜", "wN": "♞", "wB": "♝", "wQ": "♛", "wK": "♚", "wP": "♟"  # Same symbols for white
}

# Create chessboard
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim(0, BOARD_SIZE)
ax.set_ylim(0, BOARD_SIZE)

# Draw chessboard and pieces
for row in range(BOARD_SIZE):
    for col in range(BOARD_SIZE):
        color = SQUARE_COLORS[(row + col) % 2]
        ax.add_patch(plt.Rectangle((col, BOARD_SIZE - row - 1), 1, 1, color=color))

        # Get the piece at the current square
        piece = chess_board[row][col]
        if piece in piece_symbols:
            text_color = "#ffffff" if piece.startswith("w") else "black"  # Bright white for white pieces
            ax.text(col + 0.5, BOARD_SIZE - row - 0.5, piece_symbols[piece],
                    fontsize=40, ha="center", va="center", fontweight="bold",
                    fontname="DejaVu Sans", color=text_color)  # Solid effect

plt.show()

# %% [markdown]
# ## Stage 2
